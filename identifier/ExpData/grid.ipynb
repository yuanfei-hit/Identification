# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

# %%
y0 = np.loadtxt('finger_0_contact_force_timing.txt')
y1 = np.loadtxt('finger_1_contact_force_timing.txt')
y2 = np.loadtxt('finger_2_contact_force_timing.txt')
x = np.arange(0, float(y0.shape[0])/100, 0.01)
plt.xlabel('Time (s)')
plt.ylabel('Force (N)')
#plt.axis([0, float(y0.shape[0])/100-2, 0, 0.07]) 
#plt.ticklabel_format(axis='y',style='sci',scilimits=(0,1e-5))
plt.plot(x, y0, label='finger_0')
plt.plot(x, y1, label='finger_1')
plt.plot(x, y2, label='finger_2')
legend = plt.legend(loc='upper left', shadow=False, fontsize='medium')
#plt.savefig('figures/' + model + '_ContactForces.pdf')
plt.show()

# %%
y0 = np.loadtxt('contact_feature.txt')
y = y0
num = 10
#f = plt.figure(figsize=(12,6))
#ax = f.add_subplot(231)
#ax.hist(y, num);
plt.hist(y, num);
plt.xlabel('Stiffness (N/m)')
plt.ylabel('Count number')
#print y
#y = np.ma.masked_greater(y,5000)
#y = np.ma.masked_less(y,3500)
print np.mean(y) 
print np.std(y)
#print plt.hist(y, num)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-622c2122cf07> in <module>()
# ----> 1 y0 = np.loadtxt('contact_feature.txt')
#       2 y = y0
#       3 num = 10
#       4 #f = plt.figure(figsize=(12,6))
#       5 #ax = f.add_subplot(231)
#
# /home/yuanfei/miniconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     894                 fh = iter(bz2.BZ2File(fname))
#     895             elif sys.version_info[0] == 2:
# --> 896                 fh = iter(open(fname, 'U'))
#     897             else:
#     898                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'contact_feature.txt'
