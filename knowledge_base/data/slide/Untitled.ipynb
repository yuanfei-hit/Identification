# %%
import numpy as np
import matplotlib.pyplot as plt
from turtle import *
# %matplotlib inline

# %%
data = np.loadtxt('whole_slide_15.pcd')
plt.plot(data[:,0], data[:,1], '.')

# %%
num = 1000
x = np.random.random(num)
x = x/num+0.05
f = plt.figure()
ax = f.add_subplot(111) 
ax.plot(x, '.')
ax.axhline(y = 0.0505, xmin= 0, xmax=num, color = 'r' )
ax.axvline(x = 200, ymin= 0.1, ymax=0.9, color = 'r' )
ax.axhspan(min(x), max(x), facecolor = 'g', alpha = 0.1)

ax.set_xticks([])
# Out:
# []

# %%
C_0 = np.loadtxt('B/0_order.txt')
C_1 = np.loadtxt('B/1_order.txt')
C_1 = C_1[1:]
C_2 = C_1[1:] - C_1[:-1]
C_3 = C_2[1:] - C_2[:-1]
f = plt.figure(figsize=(8,6))
ax = f.add_subplot(111)
ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.plot(C_0, 'r-')
ax.plot(abs(C_1), 'g-')
ax.plot(abs(C_2), 'b-')
# ax.plot(abs(C_3), 'c-')
plt.xlim([0,C_1.shape[0]])
# plt.ylim([0,])
# plt.title('ICP s')
plt.legend(['$S_{icp}$','$|S_{icp}^{(1)}|$','$|S_{icp}^{(2)}|$'])
# f.savefig('/home/alan/Dropbox/figures/icp_scores_b.pdf')

# %%
C_0 = np.loadtxt('H/0_order.txt')
C_1 = np.loadtxt('H/1_order.txt')
num = 8
C_0 = C_0[num:]
C_1 = C_1[num+1:]
C_2 = C_1[1:] - C_1[:-1]
C_3 = C_2[1:] - C_2[:-1]
f = plt.figure(figsize=(6,4))
ax = f.add_subplot(111)
ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.plot(C_0, 'r-')
ax.plot(abs(C_1), 'g-')
ax.plot(abs(C_2), 'b-')
# ax.plot(abs(C_3), 'c-')
plt.xlim([0,C_1.shape[0]])
# plt.ylim([0,])
# plt.title('ICP s')
plt.legend(['$S_{icp}$','$|S_{icp}^{(1)}|$','$|S_{icp}^{(2)}|$'])
f.savefig('/home/alan/Dropbox/figures/icp_scores_h1.pdf')

# %%
C_0 = np.loadtxt('A/0_order.txt')
C_1 = np.loadtxt('A/1_order.txt')
num = 5
rmax = 3
C_0 = C_0[num:-rmax]
C_1 = C_1[num+1:-rmax]
C_2 = C_1[1:] - C_1[:-1]
C_3 = C_2[1:] - C_2[:-1]
f = plt.figure(figsize=(6,4))
ax = f.add_subplot(111)
ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.plot(C_0, 'r-')
ax.plot(abs(C_1), 'g-')
ax.plot(abs(C_2), 'b-')
# ax.plot(abs(C_3), 'c-')
plt.xlim([0,C_1.shape[0]])
# plt.ylim([0,])
# plt.title('ICP s')
plt.legend(['$S_{icp}$','$|S_{icp}^{(1)}|$','$|S_{icp}^{(2)}|$'])
f.savefig('/home/alan/Dropbox/figures/icp_scores_a1.pdf')

# %%
C_0 = np.loadtxt('C/0_order.txt')
C_1 = np.loadtxt('C/1_order.txt')
C_0 = C_0[4:]
C_1 = C_1[5:]
C_2 = C_1[1:] - C_1[:-1]
C_3 = C_2[1:] - C_2[:-1]
f = plt.figure(figsize=(6,4))
ax = f.add_subplot(111)
ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.plot(C_0, 'r-')
ax.plot(abs(C_1), 'g-')
ax.plot(abs(C_2), 'b-')
# ax.plot(abs(C_3), 'c-')
plt.xlim([0,C_1.shape[0]])
# plt.ylim([0,])
# plt.title('ICP s')
plt.legend(['$S_{icp}$','$|S_{icp}^{(1)}|$','$|S_{icp}^{(2)}|$'])
f.savefig('/home/alan/Dropbox/figures/icp_scores_c1.pdf')
